# %%
# Import modules
from tika import parser # PDF file parser
import pandas as pd
import glob # Unix style pathname pattern expansion
from Bio import SeqIO
from geopy.geocoders import Nominatim # Module to get coordinates
import psycopg2
from datetime import date

# %%
# Function to replace spaces to underscores in strings
def replace_spaces(string):
    return '_'.join(string.split(' '))

def remove_spaces(string):
    return '/'.join(string.split(' / '))


# Function to read the GISAID metadata PDF file and filter out unnecessary lines/fields
def read_pdf(path):
    pdf = parser.from_file(path)
    raw_content = pdf['content'].lstrip('\n')
    content_lines = raw_content.split('\n')
    filtered_content = list(filter(lambda x: x != '' and x != 'Virus detail' and x != 'Sample information' 
                          and x != 'Institute information' and x != 'Submitter information' 
                                   and (not x.lower().startswith('updated')) 
                                   and (not x.lower().startswith('note')) 
                                   and (not x.lower().startswith('please note'))
                                   and (not x.lower().startswith('apartado')), content_lines))
    return filtered_content[1:]

# %%
# Process text
def fix_content(content):
    
    authors = ''
    modified_content = []
    
    for i in range(len(content)):
        if content[i] == 'Sample ID given by the sample' and content[i+1] == 'provider:':
            content[i] = content[i] + ' ' + content[i+1]
            content.pop(i+1)
        if content[i] == 'Sample ID given by the' and content[i+1] == 'submitting laboratory:':
            content[i] = content[i] + ' ' + content[i+1]
            content.pop(i+1)

        if content[i] == 'Additional location' and content[i+1] == 'information:':
            content[i] = content[i] + ' ' + content[i+1]
            content.pop(i+1)
            
        
        if content[i].startswith('Originating lab'):
            
            while not content[i+1].startswith('Address'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)
        
        if content[i].startswith('Submitting lab'):
            
            while not content[i+1].startswith('Address'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)
                
        
        if content[i].startswith('Sample ID given by the sample provider'):
            if not content[i+1].startswith('Submitting lab'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)
                
        
        if content[i].startswith('Additional location'):
            if not content[i + 1].startswith('information') and not content[i+1].startswith('Gender'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)
                
        
        if content[i].startswith('Sample ID given by the submitting laboratory'):
            if not content[i+1].startswith('Authors'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)
                
                
        if content[i].startswith('Comment'):
            
            while not content[i + 1].startswith('Originating'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i+1)                                             

        if content[i].startswith('Authors'):
            authors = content[i]
            
            while not content[i + 1].startswith('Submitter'):
                authors = authors + ' ' + content[i + 1]
                content.pop(i + 1)
            content[i] = authors
             

        if (content[i].startswith('Address:')) and (not content[i+1].startswith('Sample')):
            if not content[i + 1].startswith('Important note'):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i + 1)
                
                
            while (not content[i + 1].startswith('Important note') and (content[i - 1].startswith('Submission'))):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i + 1)
            
            while (not content[i + 1].startswith('Sample') and (content[i-1].startswith('Originating'))):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i + 1)
                
            while (not content[i + 1].startswith('Sample') and (content[i-1].startswith('Submitting'))):
                content[i] = content[i] + ' ' + content[i + 1]
                content.pop(i + 1)
                        
        if content[i].startswith('Important note'):
            break
        modified_content.append(content[i].split(':'))
    
    return modified_content

# %%
# Function to create a pandas dataframe 
def create_dataframe(content):
    data_dict = {}
    for i in range(len(content)):
        
        if content[i][0] == 'Location':
            content[i][0] = replace_spaces(content[i][0])
            content[i][1] = remove_spaces(content[i][1])
            content[i][1] = replace_spaces(content[i][1])
            content[i][1] = content[i][1].lstrip('_')
        else:
            content[i][0] = replace_spaces(content[i][0])
            content[i][1] = replace_spaces(content[i][1]).lstrip('_')

        if content[i][0] == 'Address':
            if content[i-1][0] == 'Originating_lab':
                content[i][0] = 'Originating_lab_address'
            if content[i-1][0] == 'Submitting_lab':
                content[i][0] = 'Submitting_lab_address'
            if content[i-1][0] == 'Submission_Date':
                content[i][0] = 'Submitter_address'

        if content[i][1]:
            data_dict[content[i][0].lower()] = content[i][1]
        else:
            data_dict[content[i][0].lower()] = 'NA'
    
    df = pd.DataFrame([data_dict], columns=data_dict.keys())
    return df

# %%
# Create a list of dataframes
df_list = []
for filename in glob.glob('EPI*.pdf'):
    print(filename)
    pdf = read_pdf(filename)
    content = fix_content(pdf)
    df = create_dataframe(content)
    df_list.append(df)
# Out:
# EPI_ISL_402119.pdf
# EPI_ISL_402120.pdf
# EPI_ISL_402121.pdf
# EPI_ISL_402123.pdf
# EPI_ISL_402124.pdf
# EPI_ISL_402125.pdf
# EPI_ISL_402126.pdf
# EPI_ISL_402127.pdf
# EPI_ISL_402128.pdf
# EPI_ISL_402129.pdf
# EPI_ISL_402130.pdf
# EPI_ISL_402131.pdf
# EPI_ISL_402132.pdf
# EPI_ISL_403928.pdf
# EPI_ISL_403929.pdf
# EPI_ISL_403930.pdf
# EPI_ISL_403931.pdf
# EPI_ISL_403932.pdf
# EPI_ISL_403933.pdf
# EPI_ISL_403934.pdf
# EPI_ISL_403935.pdf
# EPI_ISL_403936.pdf
# EPI_ISL_403937.pdf
# EPI_ISL_403962.pdf
# EPI_ISL_403963.pdf
# EPI_ISL_404227.pdf
# EPI_ISL_404228.pdf
# EPI_ISL_404253.pdf
# EPI_ISL_404895.pdf
# EPI_ISL_405839.pdf
# EPI_ISL_406030.pdf
# EPI_ISL_406031.pdf
# EPI_ISL_406034.pdf
# EPI_ISL_406036.pdf
# EPI_ISL_406223.pdf
# EPI_ISL_406531.pdf
# EPI_ISL_406533.pdf
# EPI_ISL_406534.pdf
# EPI_ISL_406535.pdf
# EPI_ISL_406536.pdf
# EPI_ISL_406538.pdf
# EPI_ISL_406592.pdf
# EPI_ISL_406593.pdf
# EPI_ISL_406594.pdf
# EPI_ISL_406595.pdf
# EPI_ISL_406596.pdf
# EPI_ISL_406597.pdf
# EPI_ISL_406716.pdf
# EPI_ISL_406717.pdf
# EPI_ISL_406798.pdf
# EPI_ISL_406799.pdf
# EPI_ISL_406800.pdf
# EPI_ISL_406801.pdf
# EPI_ISL_406844.pdf
# EPI_ISL_406862.pdf
# EPI_ISL_406959.pdf
# EPI_ISL_406960.pdf
# EPI_ISL_406970.pdf
# EPI_ISL_406973.pdf
# EPI_ISL_407071.pdf
# EPI_ISL_407073.pdf
# EPI_ISL_407079.pdf
# EPI_ISL_407084.pdf
# EPI_ISL_407193.pdf
# EPI_ISL_407214.pdf
# EPI_ISL_407215.pdf
# EPI_ISL_407313.pdf
# EPI_ISL_407893.pdf
# EPI_ISL_407894.pdf
# EPI_ISL_407896.pdf
# EPI_ISL_407976.pdf
# EPI_ISL_407987.pdf
# EPI_ISL_407988.pdf
# EPI_ISL_408008.pdf
# EPI_ISL_408009.pdf
# EPI_ISL_408010.pdf
# EPI_ISL_408068.pdf
# EPI_ISL_408430.pdf
# EPI_ISL_408431.pdf
# EPI_ISL_408478.pdf
# EPI_ISL_408479.pdf
# EPI_ISL_408480.pdf
# EPI_ISL_408481.pdf
# EPI_ISL_408482.pdf
# EPI_ISL_408483.pdf
# EPI_ISL_408484.pdf
# EPI_ISL_408485.pdf
# EPI_ISL_408486.pdf
# EPI_ISL_408487.pdf
# EPI_ISL_408488.pdf
# EPI_ISL_408489.pdf
# EPI_ISL_408511.pdf
# EPI_ISL_408512.pdf
# EPI_ISL_408513.pdf
# EPI_ISL_408514.pdf
# EPI_ISL_408515.pdf
# EPI_ISL_408665.pdf
# EPI_ISL_408666.pdf
# EPI_ISL_408667.pdf
# EPI_ISL_408668.pdf
# EPI_ISL_408669.pdf
# EPI_ISL_408670.pdf
# EPI_ISL_408975.pdf
# EPI_ISL_408976.pdf
# EPI_ISL_408977.pdf
# EPI_ISL_408978.pdf
# EPI_ISL_408994.pdf
# EPI_ISL_408995.pdf
# EPI_ISL_408996.pdf
# EPI_ISL_408997.pdf
# EPI_ISL_408998.pdf
# EPI_ISL_408999.pdf
# EPI_ISL_409000.pdf
# EPI_ISL_409001.pdf
# EPI_ISL_409002.pdf
# EPI_ISL_409020.pdf
# EPI_ISL_409022.pdf
# EPI_ISL_409023.pdf
# EPI_ISL_409024.pdf
# EPI_ISL_409025.pdf
# EPI_ISL_409026.pdf
# EPI_ISL_409027.pdf
# EPI_ISL_409067.pdf
# EPI_ISL_410044.pdf
# EPI_ISL_410045.pdf
# EPI_ISL_410218.pdf
# EPI_ISL_410301.pdf
# EPI_ISL_410302.pdf
# EPI_ISL_410314.pdf
# EPI_ISL_410344.pdf
# EPI_ISL_410345.pdf
# EPI_ISL_410486.pdf
# EPI_ISL_410487.pdf
# EPI_ISL_410488.pdf
# EPI_ISL_410489.pdf
# EPI_ISL_410531.pdf
# EPI_ISL_410532.pdf
# EPI_ISL_410535.pdf
# EPI_ISL_410536.pdf
# EPI_ISL_410537.pdf
# EPI_ISL_410538.pdf
# EPI_ISL_410539.pdf
# EPI_ISL_410540.pdf
# EPI_ISL_410541.pdf
# EPI_ISL_410542.pdf
# EPI_ISL_410543.pdf
# EPI_ISL_410544.pdf
# EPI_ISL_410545.pdf
# EPI_ISL_410546.pdf
# EPI_ISL_410713.pdf
# EPI_ISL_410714.pdf
# EPI_ISL_410715.pdf
# EPI_ISL_410716.pdf
# EPI_ISL_410717.pdf
# EPI_ISL_410718.pdf
# EPI_ISL_410719.pdf
# EPI_ISL_410720.pdf
# EPI_ISL_410721.pdf
# EPI_ISL_410984.pdf
# EPI_ISL_411060.pdf
# EPI_ISL_411066.pdf
# EPI_ISL_411218.pdf
# EPI_ISL_411219.pdf
# EPI_ISL_411220.pdf
# EPI_ISL_411902.pdf
# EPI_ISL_411915.pdf
# EPI_ISL_411926.pdf
# EPI_ISL_411927.pdf
# EPI_ISL_411929.pdf
# EPI_ISL_411949.pdf
# EPI_ISL_411950.pdf
# EPI_ISL_411951.pdf
# EPI_ISL_411952.pdf
# EPI_ISL_411953.pdf
# EPI_ISL_411954.pdf
# EPI_ISL_411955.pdf
# EPI_ISL_411956.pdf
# EPI_ISL_411957.pdf
# EPI_ISL_411958.pdf
# EPI_ISL_411959.pdf
# EPI_ISL_411960.pdf
# EPI_ISL_411961.pdf
# EPI_ISL_411962.pdf
# EPI_ISL_411963.pdf
# EPI_ISL_411964.pdf
# EPI_ISL_411965.pdf
# EPI_ISL_411966.pdf
# EPI_ISL_411967.pdf
# EPI_ISL_412026.pdf
# EPI_ISL_412028.pdf
# EPI_ISL_412029.pdf
# EPI_ISL_412030.pdf
# EPI_ISL_412034.pdf
# EPI_ISL_412035.pdf
# EPI_ISL_412036.pdf
# EPI_ISL_412037.pdf
# EPI_ISL_412038.pdf
# EPI_ISL_412039.pdf
# EPI_ISL_412041.pdf
# EPI_ISL_412042.pdf
# EPI_ISL_412043.pdf
# EPI_ISL_412044.pdf
# EPI_ISL_412045.pdf
# EPI_ISL_412046.pdf
# EPI_ISL_412049.pdf
# EPI_ISL_412050.pdf
# EPI_ISL_412051.pdf
# EPI_ISL_412052.pdf
# EPI_ISL_412053.pdf
# EPI_ISL_412054.pdf
# EPI_ISL_412116.pdf
# EPI_ISL_412387.pdf
# EPI_ISL_412418.pdf
# EPI_ISL_412419.pdf
# EPI_ISL_412420.pdf
# EPI_ISL_412421.pdf
# EPI_ISL_412422.pdf
# EPI_ISL_412423.pdf
# EPI_ISL_412424.pdf
# EPI_ISL_412425.pdf
# EPI_ISL_412426.pdf
# EPI_ISL_412459.pdf
# EPI_ISL_412860.pdf
# EPI_ISL_412862.pdf
# EPI_ISL_412869.pdf
# EPI_ISL_412870.pdf
# EPI_ISL_412871.pdf
# EPI_ISL_412872.pdf
# EPI_ISL_412873.pdf
# EPI_ISL_412898.pdf
# EPI_ISL_412899.pdf
# EPI_ISL_412900.pdf
# EPI_ISL_412912.pdf
# EPI_ISL_412964.pdf
# EPI_ISL_412965.pdf
# EPI_ISL_412966.pdf
# EPI_ISL_412967.pdf
# EPI_ISL_412968.pdf
# EPI_ISL_412969.pdf
# EPI_ISL_412970.pdf
# EPI_ISL_412971.pdf
# EPI_ISL_412972.pdf
# EPI_ISL_412973.pdf
# EPI_ISL_412974.pdf
# EPI_ISL_412975.pdf
# EPI_ISL_412978.pdf
# EPI_ISL_412979.pdf
# EPI_ISL_412980.pdf
# EPI_ISL_412981.pdf
# EPI_ISL_412982.pdf
# EPI_ISL_412983.pdf
# EPI_ISL_413014.pdf
# EPI_ISL_413015.pdf
# EPI_ISL_413016.pdf
# EPI_ISL_413017.pdf
# EPI_ISL_413018.pdf
# EPI_ISL_413019.pdf
# EPI_ISL_413020.pdf
# EPI_ISL_413021.pdf
# EPI_ISL_413022.pdf
# EPI_ISL_413023.pdf
# EPI_ISL_413024.pdf
# EPI_ISL_413025.pdf
# EPI_ISL_413213.pdf
# EPI_ISL_413214.pdf
# EPI_ISL_413219.pdf
# EPI_ISL_413221.pdf
# EPI_ISL_413455.pdf
# EPI_ISL_413456.pdf
# EPI_ISL_413457.pdf
# EPI_ISL_413458.pdf
# EPI_ISL_413459.pdf
# EPI_ISL_413485.pdf
# EPI_ISL_413486.pdf
# EPI_ISL_413487.pdf
# EPI_ISL_413488.pdf
# EPI_ISL_413489.pdf
# EPI_ISL_413490.pdf
# EPI_ISL_413491.pdf
# EPI_ISL_413492.pdf
# EPI_ISL_413493.pdf
# EPI_ISL_413494.pdf
# EPI_ISL_413495.pdf
# EPI_ISL_413496.pdf
# EPI_ISL_413497.pdf
# EPI_ISL_413498.pdf
# EPI_ISL_413513.pdf
# EPI_ISL_413514.pdf
# EPI_ISL_413515.pdf
# EPI_ISL_413516.pdf
# EPI_ISL_413517.pdf
# EPI_ISL_413518.pdf
# EPI_ISL_413519.pdf
# EPI_ISL_413520.pdf
# EPI_ISL_413521.pdf
# EPI_ISL_413522.pdf
# EPI_ISL_413523.pdf
# EPI_ISL_413550.pdf
# EPI_ISL_413553.pdf
# EPI_ISL_413554.pdf
# EPI_ISL_413555.pdf
# EPI_ISL_413556.pdf
# EPI_ISL_413557.pdf
# EPI_ISL_413558.pdf
# EPI_ISL_413559.pdf
# EPI_ISL_413560.pdf
# EPI_ISL_413561.pdf
# EPI_ISL_413562.pdf
# EPI_ISL_413563.pdf
# EPI_ISL_413564.pdf
# EPI_ISL_413565.pdf
# EPI_ISL_413566.pdf
# EPI_ISL_413567.pdf
# EPI_ISL_413568.pdf
# EPI_ISL_413569.pdf
# EPI_ISL_413570.pdf
# EPI_ISL_413571.pdf
# EPI_ISL_413572.pdf
# EPI_ISL_413573.pdf
# EPI_ISL_413574.pdf
# EPI_ISL_413575.pdf
# EPI_ISL_413576.pdf
# EPI_ISL_413577.pdf
# EPI_ISL_413578.pdf
# EPI_ISL_413579.pdf
# EPI_ISL_413580.pdf
# EPI_ISL_413581.pdf
# EPI_ISL_413582.pdf
# EPI_ISL_413583.pdf
# EPI_ISL_413584.pdf
# EPI_ISL_413585.pdf
# EPI_ISL_413586.pdf
# EPI_ISL_413587.pdf
# EPI_ISL_413588.pdf
# EPI_ISL_413589.pdf
# EPI_ISL_413590.pdf
# EPI_ISL_413591.pdf
# EPI_ISL_413592.pdf
# EPI_ISL_413593.pdf
# EPI_ISL_413594.pdf
# EPI_ISL_413595.pdf
# EPI_ISL_413596.pdf
# EPI_ISL_413597.pdf
# EPI_ISL_413598.pdf
# EPI_ISL_413599.pdf
# EPI_ISL_413600.pdf
# EPI_ISL_413601.pdf
# EPI_ISL_413602.pdf
# EPI_ISL_413603.pdf
# EPI_ISL_413604.pdf
# EPI_ISL_413605.pdf
# EPI_ISL_413606.pdf
# EPI_ISL_413607.pdf
# EPI_ISL_413608.pdf
# EPI_ISL_413609.pdf
# EPI_ISL_413610.pdf
# EPI_ISL_413611.pdf
# EPI_ISL_413612.pdf
# EPI_ISL_413613.pdf
# EPI_ISL_413614.pdf
# EPI_ISL_413615.pdf
# EPI_ISL_413616.pdf
# EPI_ISL_413617.pdf
# EPI_ISL_413618.pdf
# EPI_ISL_413619.pdf
# EPI_ISL_413620.pdf
# EPI_ISL_413621.pdf
# EPI_ISL_413622.pdf
# EPI_ISL_413623.pdf
# EPI_ISL_413647.pdf
# EPI_ISL_413648.pdf
# EPI_ISL_413649.pdf
# EPI_ISL_413650.pdf
# EPI_ISL_413651.pdf
# EPI_ISL_413652.pdf
# EPI_ISL_413653.pdf
# EPI_ISL_413691.pdf
# EPI_ISL_413692.pdf
# EPI_ISL_413693.pdf
# EPI_ISL_413694.pdf
# EPI_ISL_413695.pdf
# EPI_ISL_413696.pdf
# EPI_ISL_413697.pdf
# EPI_ISL_413711.pdf
# EPI_ISL_413729.pdf
# EPI_ISL_413746.pdf
# EPI_ISL_413747.pdf
# EPI_ISL_413748.pdf
# EPI_ISL_413749.pdf
# EPI_ISL_413750.pdf
# EPI_ISL_413751.pdf
# EPI_ISL_413752.pdf
# EPI_ISL_413753.pdf
# EPI_ISL_413761.pdf
# EPI_ISL_413791.pdf
# EPI_ISL_413809.pdf
# EPI_ISL_413850.pdf
# EPI_ISL_413851.pdf
# EPI_ISL_413852.pdf
# EPI_ISL_413853.pdf
# EPI_ISL_413854.pdf
# EPI_ISL_413855.pdf
# EPI_ISL_413856.pdf
# EPI_ISL_413857.pdf
# EPI_ISL_413858.pdf
# EPI_ISL_413859.pdf
# EPI_ISL_413860.pdf
# EPI_ISL_413861.pdf
# EPI_ISL_413862.pdf
# EPI_ISL_413863.pdf
# EPI_ISL_413864.pdf
# EPI_ISL_413865.pdf
# EPI_ISL_413866.pdf
# EPI_ISL_413867.pdf
# EPI_ISL_413868.pdf
# EPI_ISL_413869.pdf
# EPI_ISL_413870.pdf
# EPI_ISL_413871.pdf
# EPI_ISL_413872.pdf
# EPI_ISL_413873.pdf
# EPI_ISL_413874.pdf
# EPI_ISL_413875.pdf
# EPI_ISL_413876.pdf
# EPI_ISL_413877.pdf
# EPI_ISL_413878.pdf
# EPI_ISL_413879.pdf
# EPI_ISL_413880.pdf
# EPI_ISL_413881.pdf
# EPI_ISL_413882.pdf
# EPI_ISL_413883.pdf
# EPI_ISL_413884.pdf
# EPI_ISL_413885.pdf
# EPI_ISL_413886.pdf
# EPI_ISL_413887.pdf
# EPI_ISL_413888.pdf
# EPI_ISL_413889.pdf
# EPI_ISL_413890.pdf
# EPI_ISL_413891.pdf
# EPI_ISL_413892.pdf
# EPI_ISL_413893.pdf
# EPI_ISL_413894.pdf
# EPI_ISL_413895.pdf
# EPI_ISL_413896.pdf
# EPI_ISL_413897.pdf
# EPI_ISL_413898.pdf
# EPI_ISL_413899.pdf
# EPI_ISL_413900.pdf
# EPI_ISL_413901.pdf
# EPI_ISL_413902.pdf
# EPI_ISL_413904.pdf
# EPI_ISL_413905.pdf
# EPI_ISL_413906.pdf
# EPI_ISL_413922.pdf
# EPI_ISL_413924.pdf
# EPI_ISL_413925.pdf
# EPI_ISL_413926.pdf
# EPI_ISL_413928.pdf
# EPI_ISL_413931.pdf
# EPI_ISL_413949.pdf
# EPI_ISL_413955.pdf
# EPI_ISL_413996.pdf
# EPI_ISL_413997.pdf
# EPI_ISL_413999.pdf
# EPI_ISL_414005.pdf
# EPI_ISL_414006.pdf
# EPI_ISL_414007.pdf
# EPI_ISL_414008.pdf
# EPI_ISL_414009.pdf
# EPI_ISL_414010.pdf
# EPI_ISL_414011.pdf
# EPI_ISL_414012.pdf
# EPI_ISL_414013.pdf
# EPI_ISL_414014.pdf
# EPI_ISL_414015.pdf
# EPI_ISL_414016.pdf
# EPI_ISL_414017.pdf
# EPI_ISL_414019.pdf
# EPI_ISL_414020.pdf
# EPI_ISL_414021.pdf
# EPI_ISL_414022.pdf
# EPI_ISL_414023.pdf
# EPI_ISL_414024.pdf
# EPI_ISL_414025.pdf
# EPI_ISL_414026.pdf
# EPI_ISL_414027.pdf
# EPI_ISL_414040.pdf
# EPI_ISL_414041.pdf
# EPI_ISL_414042.pdf
# EPI_ISL_414043.pdf
# EPI_ISL_414044.pdf
# EPI_ISL_414045.pdf
# EPI_ISL_414363.pdf
# EPI_ISL_414364.pdf
# EPI_ISL_414365.pdf
# EPI_ISL_414366.pdf
# EPI_ISL_414367.pdf
# EPI_ISL_414368.pdf
# EPI_ISL_414369.pdf
# EPI_ISL_414371.pdf
# EPI_ISL_414372.pdf
# EPI_ISL_414373.pdf
# EPI_ISL_414374.pdf
# EPI_ISL_414375.pdf
# EPI_ISL_414376.pdf
# EPI_ISL_414377.pdf
# EPI_ISL_414378.pdf
# EPI_ISL_414379.pdf
# EPI_ISL_414380.pdf
# EPI_ISL_414414.pdf
# EPI_ISL_414423.pdf
# EPI_ISL_414424.pdf
# EPI_ISL_414425.pdf
# EPI_ISL_414426.pdf
# EPI_ISL_414427.pdf
# EPI_ISL_414428.pdf
# EPI_ISL_414429.pdf
# EPI_ISL_414430.pdf
# EPI_ISL_414431.pdf
# EPI_ISL_414432.pdf
# EPI_ISL_414433.pdf
# EPI_ISL_414434.pdf
# EPI_ISL_414435.pdf
# EPI_ISL_414436.pdf
# EPI_ISL_414437.pdf
# EPI_ISL_414438.pdf
# EPI_ISL_414439.pdf
# EPI_ISL_414440.pdf
# EPI_ISL_414441.pdf
# EPI_ISL_414442.pdf
# EPI_ISL_414443.pdf
# EPI_ISL_414444.pdf
# EPI_ISL_414445.pdf
# EPI_ISL_414446.pdf
# EPI_ISL_414448.pdf
# EPI_ISL_414449.pdf
# EPI_ISL_414450.pdf
# EPI_ISL_414451.pdf
# EPI_ISL_414452.pdf
# EPI_ISL_414453.pdf
# EPI_ISL_414454.pdf
# EPI_ISL_414455.pdf
# EPI_ISL_414456.pdf
# EPI_ISL_414457.pdf
# EPI_ISL_414458.pdf
# EPI_ISL_414459.pdf
# EPI_ISL_414460.pdf
# EPI_ISL_414461.pdf
# EPI_ISL_414462.pdf
# EPI_ISL_414463.pdf
# EPI_ISL_414464.pdf
# EPI_ISL_414465.pdf
# EPI_ISL_414466.pdf
# EPI_ISL_414467.pdf
# EPI_ISL_414468.pdf
# EPI_ISL_414469.pdf
# EPI_ISL_414470.pdf
# EPI_ISL_414471.pdf
# EPI_ISL_414475.pdf
# EPI_ISL_414476.pdf
# EPI_ISL_414477.pdf
# EPI_ISL_414479.pdf
# EPI_ISL_414480.pdf
# EPI_ISL_414481.pdf
# EPI_ISL_414482.pdf
# EPI_ISL_414483.pdf
# EPI_ISL_414484.pdf
# EPI_ISL_414485.pdf
# EPI_ISL_414486.pdf
# EPI_ISL_414487.pdf
# EPI_ISL_414488.pdf
# EPI_ISL_414495.pdf
# EPI_ISL_414496.pdf
# EPI_ISL_414497.pdf
# EPI_ISL_414498.pdf
# EPI_ISL_414499.pdf
# EPI_ISL_414500.pdf
# EPI_ISL_414501.pdf
# EPI_ISL_414503.pdf
# EPI_ISL_414504.pdf
# EPI_ISL_414505.pdf
# EPI_ISL_414506.pdf
# EPI_ISL_414507.pdf
# EPI_ISL_414508.pdf
# EPI_ISL_414509.pdf
# EPI_ISL_414510.pdf
# EPI_ISL_414511.pdf
# EPI_ISL_414512.pdf
# EPI_ISL_414513.pdf
# EPI_ISL_414514.pdf
# EPI_ISL_414515.pdf
# EPI_ISL_414516.pdf
# EPI_ISL_414517.pdf
# EPI_ISL_414518.pdf
# EPI_ISL_414519.pdf
# EPI_ISL_414520.pdf
# EPI_ISL_414521.pdf
# EPI_ISL_414522.pdf
# EPI_ISL_414523.pdf
# EPI_ISL_414524.pdf
# EPI_ISL_414525.pdf
# EPI_ISL_414526.pdf
# EPI_ISL_414527.pdf
# EPI_ISL_414528.pdf
# EPI_ISL_414529.pdf
# EPI_ISL_414530.pdf
# EPI_ISL_414531.pdf
# EPI_ISL_414532.pdf
# EPI_ISL_414533.pdf
# EPI_ISL_414534.pdf
# EPI_ISL_414535.pdf
# EPI_ISL_414536.pdf
# EPI_ISL_414537.pdf
# EPI_ISL_414538.pdf
# EPI_ISL_414539.pdf
# EPI_ISL_414540.pdf
# EPI_ISL_414541.pdf
# EPI_ISL_414542.pdf
# EPI_ISL_414543.pdf
# EPI_ISL_414544.pdf
# EPI_ISL_414545.pdf
# EPI_ISL_414546.pdf
# EPI_ISL_414547.pdf
# EPI_ISL_414548.pdf
# EPI_ISL_414549.pdf
# EPI_ISL_414550.pdf
# EPI_ISL_414551.pdf
# EPI_ISL_414552.pdf
# EPI_ISL_414553.pdf
# EPI_ISL_414554.pdf
# EPI_ISL_414555.pdf
# EPI_ISL_414556.pdf
# EPI_ISL_414557.pdf
# EPI_ISL_414558.pdf
# EPI_ISL_414559.pdf
# EPI_ISL_414560.pdf
# EPI_ISL_414561.pdf
# EPI_ISL_414562.pdf
# EPI_ISL_414563.pdf
# EPI_ISL_414564.pdf
# EPI_ISL_414565.pdf
# EPI_ISL_414566.pdf
# EPI_ISL_414567.pdf
# EPI_ISL_414568.pdf
# EPI_ISL_414569.pdf
# EPI_ISL_414571.pdf
# EPI_ISL_414572.pdf
# EPI_ISL_414573.pdf
# EPI_ISL_414574.pdf
# EPI_ISL_414575.pdf
# EPI_ISL_414577.pdf
# EPI_ISL_414578.pdf
# EPI_ISL_414579.pdf
# EPI_ISL_414580.pdf
# EPI_ISL_414584.pdf
# EPI_ISL_414585.pdf
# EPI_ISL_414586.pdf
# EPI_ISL_414587.pdf
# EPI_ISL_414588.pdf
# EPI_ISL_414589.pdf
# EPI_ISL_414590.pdf
# EPI_ISL_414591.pdf
# EPI_ISL_414592.pdf
# EPI_ISL_414593.pdf
# EPI_ISL_414594.pdf
# EPI_ISL_414595.pdf
# EPI_ISL_414596.pdf
# EPI_ISL_414597.pdf
# EPI_ISL_414598.pdf
# EPI_ISL_414599.pdf
# EPI_ISL_414600.pdf
# EPI_ISL_414601.pdf
# EPI_ISL_414616.pdf
# EPI_ISL_414617.pdf
# EPI_ISL_414618.pdf
# EPI_ISL_414619.pdf
# EPI_ISL_414620.pdf
# EPI_ISL_414621.pdf
# EPI_ISL_414622.pdf
# EPI_ISL_414623.pdf
# EPI_ISL_414624.pdf
# EPI_ISL_414625.pdf
# EPI_ISL_414626.pdf
# EPI_ISL_414627.pdf
# EPI_ISL_414628.pdf
# EPI_ISL_414629.pdf
# EPI_ISL_414630.pdf
# EPI_ISL_414631.pdf
# EPI_ISL_414632.pdf
# EPI_ISL_414633.pdf
# EPI_ISL_414634.pdf
# EPI_ISL_414635.pdf
# EPI_ISL_414636.pdf
# EPI_ISL_414637.pdf
# EPI_ISL_414638.pdf
# EPI_ISL_414639.pdf
# EPI_ISL_414640.pdf
# EPI_ISL_414641.pdf
# EPI_ISL_414642.pdf
# EPI_ISL_414643.pdf
# EPI_ISL_414644.pdf
# EPI_ISL_414645.pdf
# EPI_ISL_414646.pdf
# EPI_ISL_414647.pdf
# EPI_ISL_414648.pdf
# EPI_ISL_414663.pdf
# EPI_ISL_414684.pdf
# EPI_ISL_414685.pdf
# EPI_ISL_414686.pdf
# EPI_ISL_414687.pdf
# EPI_ISL_414688.pdf
# EPI_ISL_414689.pdf
# EPI_ISL_414690.pdf
# EPI_ISL_414691.pdf
# EPI_ISL_414692.pdf
# EPI_ISL_414934.pdf
# EPI_ISL_414935.pdf
# EPI_ISL_414936.pdf
# EPI_ISL_414937.pdf
# EPI_ISL_414938.pdf
# EPI_ISL_414939.pdf
# EPI_ISL_414940.pdf
# EPI_ISL_414941.pdf
# EPI_ISL_414945.pdf
# EPI_ISL_414946.pdf
# EPI_ISL_414948.pdf
# EPI_ISL_414949.pdf
# EPI_ISL_415041.pdf
# EPI_ISL_415045.pdf
# EPI_ISL_415046.pdf
# EPI_ISL_415047.pdf
# EPI_ISL_415105.pdf
# EPI_ISL_415128.pdf
# EPI_ISL_415129.pdf
# EPI_ISL_415130.pdf
# EPI_ISL_415131.pdf
# EPI_ISL_415132.pdf
# EPI_ISL_415133.pdf
# EPI_ISL_415134.pdf
# EPI_ISL_415135.pdf
# EPI_ISL_415136.pdf
# EPI_ISL_415137.pdf
# EPI_ISL_415138.pdf
# EPI_ISL_415139.pdf
# EPI_ISL_415140.pdf
# EPI_ISL_415141.pdf
# EPI_ISL_415142.pdf
# EPI_ISL_415143.pdf
# EPI_ISL_415144.pdf
# EPI_ISL_415145.pdf
# EPI_ISL_415146.pdf
# EPI_ISL_415147.pdf
# EPI_ISL_415148.pdf
# EPI_ISL_415149.pdf
# EPI_ISL_415150.pdf
# EPI_ISL_415151.pdf
# EPI_ISL_415152.pdf
# EPI_ISL_415153.pdf
# EPI_ISL_415154.pdf
# EPI_ISL_415155.pdf
# EPI_ISL_415156.pdf
# EPI_ISL_415157.pdf
# EPI_ISL_415158.pdf
# EPI_ISL_415159.pdf
# EPI_ISL_415435.pdf
# EPI_ISL_415453.pdf
# EPI_ISL_415454.pdf
# EPI_ISL_415455.pdf
# EPI_ISL_415456.pdf
# EPI_ISL_415457.pdf
# EPI_ISL_415458.pdf
# EPI_ISL_415459.pdf
# EPI_ISL_415460.pdf
# EPI_ISL_415461.pdf
# EPI_ISL_415462.pdf
# EPI_ISL_415463.pdf
# EPI_ISL_415464.pdf
# EPI_ISL_415465.pdf
# EPI_ISL_415466.pdf
# EPI_ISL_415467.pdf
# EPI_ISL_415468.pdf
# EPI_ISL_415469.pdf
# EPI_ISL_415470.pdf
# EPI_ISL_415471.pdf
# EPI_ISL_415472.pdf
# EPI_ISL_415473.pdf
# EPI_ISL_415474.pdf
# EPI_ISL_415475.pdf
# EPI_ISL_415476.pdf
# EPI_ISL_415477.pdf
# EPI_ISL_415478.pdf
# EPI_ISL_415479.pdf
# EPI_ISL_415480.pdf
# EPI_ISL_415481.pdf
# EPI_ISL_415482.pdf
# EPI_ISL_415483.pdf
# EPI_ISL_415484.pdf
# EPI_ISL_415485.pdf
# EPI_ISL_415486.pdf
# EPI_ISL_415487.pdf
# EPI_ISL_415488.pdf
# EPI_ISL_415489.pdf
# EPI_ISL_415490.pdf
# EPI_ISL_415491.pdf
# EPI_ISL_415492.pdf
# EPI_ISL_415493.pdf
# EPI_ISL_415494.pdf
# EPI_ISL_415495.pdf
# EPI_ISL_415496.pdf
# EPI_ISL_415497.pdf
# EPI_ISL_415498.pdf
# EPI_ISL_415499.pdf
# EPI_ISL_415500.pdf
# EPI_ISL_415501.pdf
# EPI_ISL_415502.pdf
# EPI_ISL_415503.pdf
# EPI_ISL_415504.pdf
# EPI_ISL_415505.pdf
# EPI_ISL_415506.pdf
# EPI_ISL_415507.pdf
# EPI_ISL_415508.pdf
# EPI_ISL_415509.pdf
# EPI_ISL_415510.pdf
# EPI_ISL_415511.pdf
# EPI_ISL_415512.pdf
# EPI_ISL_415513.pdf
# EPI_ISL_415514.pdf
# EPI_ISL_415515.pdf
# EPI_ISL_415516.pdf
# EPI_ISL_415517.pdf
# EPI_ISL_415518.pdf
# EPI_ISL_415519.pdf
# EPI_ISL_415520.pdf
# EPI_ISL_415521.pdf
# EPI_ISL_415522.pdf
# EPI_ISL_415523.pdf
# EPI_ISL_415524.pdf
# EPI_ISL_415525.pdf
# EPI_ISL_415526.pdf
# EPI_ISL_415527.pdf
# EPI_ISL_415528.pdf
# EPI_ISL_415529.pdf
# EPI_ISL_415530.pdf
# EPI_ISL_415531.pdf
# EPI_ISL_415532.pdf
# EPI_ISL_415533.pdf
# EPI_ISL_415534.pdf
# EPI_ISL_415535.pdf
# EPI_ISL_415536.pdf
# EPI_ISL_415537.pdf
# EPI_ISL_415538.pdf
# EPI_ISL_415539.pdf
# EPI_ISL_415540.pdf
# EPI_ISL_415541.pdf
# EPI_ISL_415542.pdf
# EPI_ISL_415543.pdf
# EPI_ISL_415544.pdf
# EPI_ISL_415577.pdf
# EPI_ISL_415578.pdf
# EPI_ISL_415579.pdf
# EPI_ISL_415580.pdf
# EPI_ISL_415581.pdf
# EPI_ISL_415582.pdf
# EPI_ISL_415583.pdf
# EPI_ISL_415584.pdf
# EPI_ISL_415585.pdf
# EPI_ISL_415586.pdf
# EPI_ISL_415587.pdf
# EPI_ISL_415588.pdf
# EPI_ISL_415589.pdf
# EPI_ISL_415590.pdf
# EPI_ISL_415591.pdf
# EPI_ISL_415592.pdf
# EPI_ISL_415593.pdf
# EPI_ISL_415594.pdf
# EPI_ISL_415595.pdf
# EPI_ISL_415596.pdf
# EPI_ISL_415597.pdf
# EPI_ISL_415598.pdf
# EPI_ISL_415599.pdf
# EPI_ISL_415600.pdf
# EPI_ISL_415601.pdf
# EPI_ISL_415602.pdf
# EPI_ISL_415603.pdf
# EPI_ISL_415604.pdf
# EPI_ISL_415605.pdf
# EPI_ISL_415606.pdf
# EPI_ISL_415607.pdf
# EPI_ISL_415608.pdf
# EPI_ISL_415609.pdf
# EPI_ISL_415610.pdf
# EPI_ISL_415611.pdf
# EPI_ISL_415612.pdf
# EPI_ISL_415613.pdf
# EPI_ISL_415614.pdf
# EPI_ISL_415615.pdf
# EPI_ISL_415616.pdf
# EPI_ISL_415617.pdf
# EPI_ISL_415618.pdf
# EPI_ISL_415619.pdf
# EPI_ISL_415620.pdf
# EPI_ISL_415621.pdf
# EPI_ISL_415622.pdf
# EPI_ISL_415623.pdf
# EPI_ISL_415624.pdf
# EPI_ISL_415625.pdf
# EPI_ISL_415626.pdf
# EPI_ISL_415627.pdf
# EPI_ISL_415628.pdf
# EPI_ISL_415629.pdf
# EPI_ISL_415630.pdf
# EPI_ISL_415631.pdf
# EPI_ISL_415632.pdf
# EPI_ISL_415633.pdf
# EPI_ISL_415634.pdf
# EPI_ISL_415635.pdf
# EPI_ISL_415636.pdf
# EPI_ISL_415637.pdf
# EPI_ISL_415638.pdf
# EPI_ISL_415639.pdf
# EPI_ISL_415640.pdf
# EPI_ISL_415641.pdf
# EPI_ISL_415642.pdf
# EPI_ISL_415643.pdf
# EPI_ISL_415644.pdf
# EPI_ISL_415646.pdf
# EPI_ISL_415648.pdf
# EPI_ISL_415649.pdf
# EPI_ISL_415650.pdf
# EPI_ISL_415651.pdf
# EPI_ISL_415652.pdf
# EPI_ISL_415653.pdf
# EPI_ISL_415654.pdf
# EPI_ISL_415655.pdf
# EPI_ISL_415656.pdf
# EPI_ISL_415657.pdf
# EPI_ISL_415658.pdf
# EPI_ISL_415659.pdf
# EPI_ISL_415660.pdf
# EPI_ISL_415661.pdf
# EPI_ISL_415692.pdf
# EPI_ISL_415693.pdf
# EPI_ISL_415694.pdf
# EPI_ISL_415695.pdf
# EPI_ISL_415696.pdf
# EPI_ISL_415697.pdf
# EPI_ISL_415698.pdf
# EPI_ISL_415699.pdf
# EPI_ISL_415700.pdf
# EPI_ISL_415701.pdf
# EPI_ISL_415702.pdf
# EPI_ISL_415703.pdf
# EPI_ISL_415704.pdf
# EPI_ISL_415705.pdf
# EPI_ISL_415706.pdf
# EPI_ISL_415707.pdf
# EPI_ISL_415708.pdf
# EPI_ISL_415709.pdf
# EPI_ISL_415711.pdf

# %%
# Concatenate dataframes into 1 dataframe
data = pd.concat(df_list, sort=False)

# %%
# Get unique locations
locations = (data['location'].unique())
# Create a coordinate dictionary and initiate geolocator object
coordinates = {}
geolocator = Nominatim(user_agent='covid-locations')

def remove_underscore(string):
    return ' '.join(string.split('_'))

# Get coordinates for each location
def get_coords(locations):
    for location in locations:
        precise_location = ''
        if location == 'North_America/USA/Washington':
            precise_location = 'Washington, Seattle'
        else:
            if location.startswith('North_America'):
                precise_location = remove_underscore(', '.join(location.split('/')[-2:]))
            else:
                precise_location = ' '.join(location.split('/')[-1].split('_'))
        loc_coordinates = geolocator.geocode(precise_location)
        print(location)
        coordinates[location] = [loc_coordinates.latitude, loc_coordinates.longitude]
        


# Retrieve data in chucnk to avoid errors if there are too many requests
# First 50 locations
get_coords(locations[:50])
# Out:
# Asia/China/Hubei/Wuhan
# Asia/China
# Asia/Japan/Kanagawa
# Asia/China/Yunnan/Pu'er
# Asia/China/Guandong/Shenzhen
# Asia/China/Guangdong/Shenzhen
# Asia/China/Guangdong/Zhuhai
# Asia/Thailand/Nonthaburi
# Asia/China/Zhejiang
# North_America/USA/Illinois/Chicago
# North_America/USA/Washington/Snohomish_County
# Asia/Taiwan/Kaohsiung
# North_America/USA/California/Los_Angeles
# North_America/USA/California/Orange_County
# North_America/USA/Arizona/Phoenix
# Asia/China/Guangdong/Guangzhou
# Asia/China/Guangdong/Foshan
# Asia/China/Guangdong
# Europe/France/Ile-de-France/Paris
# Asia/China/Wuhan
# Oceania/Australia/Victoria/Clayton
# Europe/Germany/Bavaria/Munich
# Europe/Italy/Rome
# Asia/China/Zhejiang/Hangzhou
# Asia/Singapore
# Europe/England
# Europe/Finland/Lapland
# Asia/Japan/Aichi
# Asia/South_Korea/Gyeonggi-do
# North_America/USA/Washington
# Oceania/Australia/New_South_Wales/Sydney
# Oceania/Australia/Queensland/Gold_Coast
# Europe/Belgium/Leuven
# North_America/USA/California
# Asia/China/Chongqinq/Yongchuan
# Asia/China/Chongqing/Zhongxian
# Asia/China/Yunnan/Kunming
# Asia/China/Chongqing
# Asia/China/Shandong/Qingdao
# Asia/China/Shanghai
# Asia/China/Sichuan/Chengdu
# Asia/China/Beijing
# Asia/China/Jiangxi/Pingxiang
# Asia/China/Henan/Zhengzhou
# Asia/China/Jiangsu/Huaian
# Asia/Taiwan/Taipei
# Asia/Japan/Tokyo
# Asia/Vietnam/Thanh_Hoa
# Asia/Japan/Kyoto
# North_America/USA/Wisconsin

# %%
# 50 - 99
get_coords(locations[50:100])
# Out:
# Asia/Hong_Kong
# North_America/USA/Massachusetts
# North_America/USA/Illinois
# Asia/Nepal/Kathmandu
# Asia/Philippines
# Europe/France/Rhone-Alpes/Contamines
# Asia/Malaysia
# Asia/Japan/Nara
# Asia/Japan/Osaka
# Asia/China/Guangxi
# Asia/China/Fujian
# Asia/Cambodia/Sihanoukville
# Asia/Taiwan/Taoyuan
# Asia/South_Korea
# Asia/China/Jiangsu
# Europe/Sweden
# North_America/USA/Texas
# Asia/China/HuaShang
# Asia/China/Anhui/Hefei
# Asia/China/Shenzhen
# Asia/China/Shandong/Linyi_county
# Asia/China/Shandong/Linyi
# Asia/China/Hubei/Jingzhou
# North_America/USA/California/Solano
# Asia/South_Korea_/Seoul
# Asia/South_Korea/_Seoul
# Asia/South_Korea/Seoul
# Asia/South_Korea/Chungcheongnam-do
# Europe/Germany/Baden-Wuerttemberg
# South_America/Brazil/Sao_Paulo/Sao_Paulo
# North_America/Canada/British_Columbia
# Asia/China/Guangzhou
# Asia/Japan
# Europe/Finland/Helsinki
# North_America/Mexico/Mexico_City
# Europe/Italy/Lombardy
# Asia/China/Hubei/Tianmen
# North_America/Canada/Ontario
# South_America/Brazil/Sao_Paulo/_Sao_Paulo
# Europe/Switzerland/Zurich
# Asia/Indonesia/West_Java/Indramayu
# Europe/Scotland
# North_America/USA/Washington/King_County
# Asia/China/Anhui/Suzhou
# Europe/Germany/North_Rhine_Westphalia/Heinsberg_District
# Europe/Italy/Lombardy/Milan
# Oceania/New_Zealand/Auckland
# Asia/Iran
# Asia/India/Kerala
# Africa/Nigeria/Lagos

# %%
# 100 - 150
get_coords(locations[100:150])
# Out:
# Asia/Iran/Tehran
# Europe/United_Kingdom/Wales
# North_America/USA/California/Sonoma_County
# North_America/USA/California/Solano_County
# Europe/Netherlands/Andel
# Europe/Netherlands/Berlicum
# Europe/Netherlands/Blaricum
# Europe/Netherlands/Coevorden
# Europe/Netherlands/Dalen
# Europe/Netherlands/Delft
# Europe/Netherlands/Diemen
# Europe/Netherlands/Eindhoven
# Europe/Netherlands/Haarlem
# Europe/Netherlands/Hardinxveld_Giessendam
# Europe/Netherlands/Helmond
# Europe/Netherlands/Houten
# Europe/Netherlands/Loon_op_zand
# Europe/Netherlands/Naarden
# Europe/Netherlands/Nieuwendijk
# Europe/Netherlands/Nootdorp
# Europe/Netherlands/Oisterwijk
# Europe/Netherlands/Oss
# Europe/Netherlands/Rotterdam
# Europe/Netherlands/Tilburg
# Europe/Netherlands/Utrecht
# Europe/Netherlands/Zeewolde
# Europe/Luxemburg
# Oceania/Australia/NSW/Sydney
# North_America/USA
# Europe/Portugal
# Asia/China_/Guangdong
# Asia/Iran/_Qom
# North_America/USA/California/San_Francisco
# Europe/Switzerland/Tessin
# Europe/Switzerland/Geneva
# Europe/Switzerland/Argovie
# Europe/United_Kingdom/England
# Europe/Switzerland/Basel
# Europe/Switzerland/Vaud
# South_America/Brazil/Rio_de_Janeiro/Rio_de_Janeiro
# Asia/Iran_/Qom
# Asia/Iran/Qom
# Asia/Indonesia/Depok
# Asia/Indonesia/Jakarta
# Europe/Netherlands/Gelderland
# Europe/Netherlands/Limburg
# Europe/Netherlands/Noord_Brabant
# Europe/Netherlands/Noord_Holland
# Europe/Netherlands/Overijssel
# Europe/Netherlands/Zuid_Holland

# %%
# 150 - N
get_coords(locations[150:])
# Out:
# North_America/USA/New_York
# Europe/Czech_Republic/Usti_nad_Labem
# Europe/Ireland/Cork
# Europe/Spain/Comunitat_Valenciana/Valencia
# Europe/United_Kingdom/England/Yorkshire/Sheffield
# Europe/Germany/North_Rhine_Westphalia/Duesseldorf
# Asia/China/_Shanghai
# Europe/Italy
# Asia/India
# Europe/Germany/Munich
# Asia/Iran/Tehran/Nazi_Abad
# South_America/Chile/Talca
# South_America/Chile/Santiago
# Europe/Ireland/Dublin
# Europe/Ireland/Limerick
# North_America/USA/Minnesota
# North_America/USA/Washington/Kirkland
# North_America/USA/Washington/Tacoma
# Europe/Spain/Comunitat_Valenciana_/Valencia
# Europe/Italy/Cagliari
# Europe/France/Grand-Est/Strasbourg
# Europe/France/Normandie/Rouen
# North_America/USA/Washington/Seattle
# Europe/France/Pays_de_la_Loire/Nantes
# Europe/France/Hauts_de_France/Crépy_en_Valois
# Europe/France/Hauts_de_France/Compiègne
# Europe/France/Grand-Est/Reims
# Europe/France/Ile-de-France/Pontoise
# North_America/USA/New_York/Nassau_County
# Europe/Finland
# Africa/Congo/Kinshasa
# North_America/USA/California/San_Diego_County
# Asia/China/Shandong
# Europe/United_Kingdom/Northern_Ireland
# Asia/China/Guangdong/Zhongshan
# South_America/Brazil/Bahia/Feira_de_Santana
# South_America/Brazil/Espirito_Santo/Vila_Velha
# Central_America/Panama/Panama_City
# Europe/Belgium/Huldenberg
# Europe/Belgium/Kraainem
# Europe/Belgium/Sint-Niklaas
# Europe/Belgium/Brussels
# Europe/United_Kingdom/Wales/Cardiff
# Europe/Switzerland
# Europe/Switzerland/Genève
# Europe/Netherlands/Flevoland
# Europe/Netherlands
# North_America/USA/Utah
# Europe/United_Kingdom/Scotland
# Asia/Georgia/Tbilisi
# Europe/France/Hauts-de-France/Crépy-en_-Valois
# Europe/France/IDF
# Europe/France/Bourgogne-France-Comté/Montreux-Chateau
# Europe/France/Bourgogne-France-Comté/Thise
# Asia/China/Hangzhou

# %%
# Add coordinate data to the dataframe
for location in coordinates:
    data.loc[data.location == location, 'latitude'] = coordinates[location][0]
    data.loc[data.location == location, 'longitude'] = coordinates[location][1]

# %%
# Add country and city/state/province data

countries = []
cities_states_provinces = []
country_and_city_data = {}
for location in locations:
    loc = location.split('/')
    if len(loc) == 2:
        country = loc[1].lstrip('_').rstrip('_')
        loc_data = {'country': country, 'city/state/province': country}
        country_and_city_data[location] = loc_data
        countries.append(country)
    else:
        country = loc[1].lstrip('_').rstrip('_')
        city_state_province = loc[-1].lstrip('_').rstrip('_')
        countries.append(country)
        cities_states_provinces.append(city_state_province)
        loc_data = {'country': country, 'city/state/province': city_state_province}
        country_and_city_data[location] = loc_data

        
unique_countries = set(countries)
unique_cities_states_provinces = set(cities_states_provinces)

# Country ids

country_ids = {}
i = 1
for country in unique_countries:
    country_ids[country] = i
    i += 1
    
# City/State/Province ids
city_state_province_ids = {}
i = 1
for location in unique_cities_states_provinces:
    city_state_province_ids[location] = i
    i += 1
    

# Add country and city columns
for location in country_and_city_data:
    country = country_and_city_data[location]['country']
    city = country_and_city_data[location]['city/state/province']
    data.loc[data.location == location, 'country'] = country
    data.loc[data.location == location, 'city/state/province'] = city

# %%
# Location info
conn_string = "host='borreliabase.org' dbname='bb3-dev' user='' password=''"
conn = psycopg2.connect(conn_string)
cursor = conn.cursor()
geo_query = 'SELECT * FROM CV_GEO ORDER BY geo_id;'
country_query = 'SELECT * FROM COUNTRY ORDER BY country_id;'

def get_table(query):
    cursor.execute(query)
    records = cursor.fetchall()
    table_description = cursor.description
    
    # Column names
    cols = []
    for column in table_description:
        cols.append(column.name)
        
    # Table data
    data = []
    for row in records:
        data.append(list(row))
    df = pd.DataFrame(data, columns = cols)
    return df


geo_table = get_table(geo_query)
country_table = get_table(country_query)
geo_table['geo_name'] = geo_table['geo_name'].apply(lambda x: ':'.join([item.replace(' ', '_') for item in x.split(':')]))

# %%
cursor.execute(country_query)
records = cursor.fetchall()
country_id_dict = {}
for country in records:
    country_name = replace_spaces(country[1])
    if country_name == 'German':
        country_name = 'Germany'
    country_id_dict[country_name] = country[0]

# %%
for country in country_id_dict:
    country_name = replace_spaces(country)
    data.loc[data.country == country_name, 'country_id'] = country_id_dict[country_name]

# %%
# Create new location table
current_locations = [replace_spaces(loc) for loc in geo_table.geo_name.values]
new_locations = []
for loc in locations:
    temp = [item.rstrip('_').lstrip('_') for item in loc.split('/')]
    area = temp[0]
    area_id = 0
    
    if area == 'North_America':
        area_id = 1
    elif area == 'South_America':
        area_id = 2
    elif area == 'Europe':
        area_id = 3
    elif area == 'Asia':
        area_id = 4
    elif area == 'Africa':
        area_id = 5
    elif area == 'Oceania':
        area_id = 6
    elif area == 'Central_America':
        area_id = 7
    
    geo_name = ':'.join(temp[1:])
    if geo_name == 'China:Wuhan':
        geo_name = 'China:Hubei:Wuhan'
    if geo_name == 'China:Guandong:Shenzhen':
        geo_name = 'China:Guangdong:Shenzhen'
    if geo_name == 'USA:California:Los_Angeles':
        geo_name = 'USA:California:LA'
    if geo_name == 'China:Chongqinq:Yongchuan':
        geo_name = 'China:Chongqing:Yongchuan'
    if geo_name == 'Hong_Kong':
        geo_name = 'China:Hong_Kong'
    if geo_name == 'England':
        geo_name = 'United_Kingdom:England'
    if geo_name not in current_locations:
        new_locations.append([geo_name, area_id])

# %%
cols = ['geo_name', 'country_name', 'latitude', 'longitude', 'country_id', 'area_id', 'geo_id']
new_location_data = []
current_geo_id = max(geo_table.loc[geo_table.geo_id < 500, 'geo_id'].values) + 1

current_na_id = max(country_table.loc[(country_table.country_id < 200) 
                                      & (country_table.country_id > 100), 'country_id'].values) + 1
current_sa_id = max(country_table.loc[(country_table.country_id < 300) 
                                      & (country_table.country_id > 200), 'country_id'].values) + 1
current_eu_id = max(country_table.loc[(country_table.country_id < 400) 
                                      & (country_table.country_id > 300), 'country_id'].values) + 1
current_as_id = max(country_table.loc[(country_table.country_id < 500) 
                                      & (country_table.country_id > 400), 'country_id'].values) + 1
current_af_id = max(country_table.loc[(country_table.country_id < 600) 
                                      & (country_table.country_id > 500), 'country_id'].values) + 1
current_oc_id = max(country_table.loc[(country_table.country_id < 700) 
                                      & (country_table.country_id > 600), 'country_id'].values) + 1
# current_ca_id = max(country_table.loc[(country_table.country_id < 800) 
#                                       & (country_table.country_id > 700), 'country_id'].values) + 1
current_ca_id = 701

for loc in new_locations:
    
    temp = loc[0].split(':')
    country_name = temp[0]
    area_id = loc[1]


       
    precise_location = ''
    if len(temp) > 1:
        precise_location = ', '.join(temp[1:])
    else:
        precise_location = temp[0]
    geo_info = geolocator.geocode(remove_underscore(precise_location), language='en')
    
    country_id = 0
    if country_name in country_id_dict.keys():
        country_id = country_id_dict[country_name]
    else:
        if area_id == 1:
            country_id = current_na_id
            current_na_id += 1
        elif area_id == 2:
            country_id = current_sa_id
            current_sa_id += 1
        elif area_id == 3:
            country_id = current_eu_id
            current_eu_id += 1
        elif area_id == 4:
            country_id = current_as_id
            current_as_id += 1
        elif area_id == 5:
            country_id = current_af_id
            current_af_id += 1
        elif area_id == 6:
            country_id = current_oc_id
            current_oc_id += 1
        elif area_id == 7:
            country_id = current_ca_id
            current_ca_id += 1
            
        
        
    geo_name = loc[0]
    geo_id = current_geo_id
    current_geo_id += 1
        
    new_location_data.append(
        [
            geo_name, 
            country_name, 
            geo_info.latitude, 
            geo_info.longitude, 
            country_id, 
            area_id, 
            geo_id
        ])

new_location_df = pd.DataFrame(new_location_data, columns=cols)
new_location_df = new_location_df.sort_values('country_id')

# %%
geo_dict = {}
for index, row in geo_table.iterrows():
    geo_name = row.geo_name
    geo_dict[geo_name] = {
        'geo_id': row.geo_id,
        'area_id': row.area_id,
        'country_id': row.country_id
    }
    
new_geo_dict = {}
for index, row in new_location_df.iterrows():
    geo_name = row.geo_name
    new_geo_dict[geo_name] = {
        'area_id': row.area_id,
        'geo_id': row.geo_id,
        'country_id': row.country_id
    }


    
    
for location in locations:
    geo_name = ':'.join([item.rstrip('_').lstrip('_') for item in location.split('/')[1:]])
    if geo_name == 'China:Wuhan':
        geo_name = 'China:Hubei:Wuhan'
    if geo_name == 'China:Guandong:Shenzhen':
        geo_name = 'China:Guangdong:Shenzhen'
    if geo_name == 'USA:California:Los_Angeles':
        geo_name = 'USA:California:LA'
    if geo_name == 'China:Chongqinq:Yongchuan':
        geo_name = 'China:Chongqing:Yongchuan'
    if geo_name == 'Hong_Kong':
        geo_name = 'China:Hong_Kong'
    if geo_name == 'England':
        geo_name = 'United_Kingdom:England'
        
        
    data.loc[data.location == location, 'geo_name'] = geo_name
    if geo_name in geo_dict.keys(): 
        data.loc[data.location == location, 'geo_id'] = geo_dict[geo_name]['geo_id']
        data.loc[data.location == location, 'area_id'] =  geo_dict[geo_name]['area_id']
        data.loc[data.location == location, 'country_id'] = geo_dict[geo_name]['country_id']
       
    if geo_name in new_geo_dict.keys():
        data.loc[data.location == location, 'geo_id'] = new_geo_dict[geo_name]['geo_id']
        data.loc[data.location == location, 'area_id'] = new_geo_dict[geo_name]['area_id']
        data.loc[data.location == location, 'country_id'] = new_geo_dict[geo_name]['country_id']

# %%
data
# Out:
#                           virus_name    accession_id             type  \
# 0      BetaCoV/Wuhan/IVDC-HB-01/2019  EPI_ISL_402119  betacoronavirus
# 0      BetaCoV/Wuhan/IVDC-HB-04/2020  EPI_ISL_402120  betacoronavirus
# 0      BetaCoV/Wuhan/IVDC-HB-05/2019  EPI_ISL_402121  betacoronavirus
# 0   BetaCoV/Wuhan/IPBCAMS-WH-01/2019  EPI_ISL_402123  betacoronavirus
# 0           BetaCoV/Wuhan/WIV04/2019  EPI_ISL_402124  betacoronavirus
# ..                               ...             ...              ...
# 0    hCoV-19/Switzerland/GE062072020  EPI_ISL_415706  betacoronavirus
# 0    hCoV-19/Switzerland/GE6679/2020  EPI_ISL_415707  betacoronavirus
# 0    hCoV-19/Switzerland/GE4984/2020  EPI_ISL_415708  betacoronavirus
# 0       hCoV-19/Hangzhou/ZJU-01/2020  EPI_ISL_415709  betacoronavirus
# 0       hCoV-19/Hangzhou/ZJU-05/2020  EPI_ISL_415711  betacoronavirus
#
#      passage_details/history collection_date                location   host  \
# 0   Virus_Isolate,_Passage_1      2019-12-30  Asia/China/Hubei/Wuhan  Human
# 0                   Original      2020-01-01  Asia/China/Hubei/Wuhan  Human
# 0                   Original      2019-12-30  Asia/China/Hubei/Wuhan  Human
# 0                   Original      2019-12-24  Asia/China/Hubei/Wuhan  Human
# 0                   Original      2019-12-30  Asia/China/Hubei/Wuhan  Human
# ..                       ...             ...                     ...    ...
# 0                   Original      2020-03-06      Europe/Switzerland  Human
# 0                   Original      2020-03-08      Europe/Switzerland  Human
# 0                   Original      2020-03-07      Europe/Switzerland  Human
# 0                       Vero      2020-01-25     Asia/China/Hangzhou  Human
# 0                       Vero      2020-01-22     Asia/China/Hangzhou  Human
#
#    additional_location_information   gender patient_age  ...  \
# 0                               NA   Female          49  ...
# 0                               NA     Male          61  ...
# 0                               NA     Male          32  ...
# 0                               NA     Male          65  ...
# 0                               NA   Female          49  ...
# ..                             ...      ...         ...  ...
# 0                               NA  unknwon          32  ...
# 0                               NA  unknown          85  ...
# 0                               NA  unknown          39  ...
# 0                               NA     Male          36  ...
# 0                               NA   Female          25  ...
#
#                                     submitter_address comment   latitude  \
# 0   National_Institute_for_Viral_Disease_Control_a...     NaN  30.595105
# 0   National_Institute_for_Viral_Disease_Control_a...     NaN  30.595105
# 0   National_Institute_for_Viral_Disease_Control_a...     NaN  30.595105
# 0   No._9_Dong_Dan_San_Tiao,_Dong_Cheng_District,_...     NaN  30.595105
# 0              44_Xiao_Hong_Shan,_Wuhan,_Hubei_430071     NaN  30.595105
# ..                                                ...     ...        ...
# 0                                                  NA      NA  46.798562
# 0                                                  NA      NA  46.798562
# 0                                                  NA      NA  46.798562
# 0                                                  NA      NA  30.248963
# 0                                                  NA      NA  30.248963
#
#      longitude      country city/state/province country_id           geo_name  \
# 0   114.299935        China               Wuhan      401.0  China:Hubei:Wuhan
# 0   114.299935        China               Wuhan      401.0  China:Hubei:Wuhan
# 0   114.299935        China               Wuhan      401.0  China:Hubei:Wuhan
# 0   114.299935        China               Wuhan      401.0  China:Hubei:Wuhan
# 0   114.299935        China               Wuhan      401.0  China:Hubei:Wuhan
# ..         ...          ...                 ...        ...                ...
# 0     8.231974  Switzerland         Switzerland      307.0        Switzerland
# 0     8.231974  Switzerland         Switzerland      307.0        Switzerland
# 0     8.231974  Switzerland         Switzerland      307.0        Switzerland
# 0   120.205234        China            Hangzhou      401.0     China:Hangzhou
# 0   120.205234        China            Hangzhou      401.0     China:Hangzhou
#
#    geo_id area_id
# 0    71.0     4.0
# 0    71.0     4.0
# 0    71.0     4.0
# 0    71.0     4.0
# 0    71.0     4.0
# ..    ...     ...
# 0    17.0     3.0
# 0    17.0     3.0
# 0    17.0     3.0
# 0    81.0     4.0
# 0    81.0     4.0
#
# [958 rows x 38 columns]

# %%
current_date = date.today()
file_date = str(current_date.month) + '-' + str(current_date.day)

# Write to file
data.to_excel('gisaid-covid19-' + file_date + '.xlsx', index=False)
data.to_csv('gisaid-covid19-' + file_date + '.tsv', index=False, sep='\t')
new_location_df.to_csv('new-geo-data-' + file_date + '.tsv', sep='\t')

# %% [markdown]
# ## FASTA files

# %%
records = []
for fasta in glob.glob('EPI*.fasta'):
    fh = open(fasta)
    sequence = SeqIO.read(fh, 'fasta')
    fh.close()
    records.append(sequence)

# %%
SeqIO.write(records, 'covid-' + file_date + '.fasta', 'fasta')
# Out:
# 958
